# %%
data=read.csv("distance.csv")
data=data[,-1]
h=hclust(as.dist(data) )
plot(h)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
colnames(data)=1:(dim(data)[1])

# %%
write.csv(colnames(data)[cutree(h,k=3) ==1],"第一类.csv")
write.csv(colnames(data)[cutree(h,k=3) ==2],"第二类.csv")
write.csv(colnames(data)[cutree(h,k=3) ==3],"第三类.csv")
#write.csv(colnames(data)[cutree(h,k=6) ==4],"第四类.csv")
#write.csv(colnames(data)[cutree(h,k=6) ==5],"第五类.csv")
#write.csv(colnames(data)[cutree(h,k=6) ==6],"第六类.csv")
#write.csv(colnames(data)[cutree(h,k=7) ==7],"第七类.csv")

# %%
colnames(data)[cutree(h,k=7) ==1]
# Out:
# [1] "1"  "3"  "4"  "5"  "6"  "13" "23"
