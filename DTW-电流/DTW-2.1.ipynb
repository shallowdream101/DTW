# %%
import numpy as np
import pandas as pd
data=pd.read_csv("work_data.csv")

# %%
data=data[['time','Im','flag']]

# %%
#data=data.groupby(["time",'flag']).mean().reset_index()

# %%
#data['time'] = pd.to_datetime(data['time'])

# %%
#data.sort_values(by='time',inplace=True)

# %%
#data.index=list(range(610))

# %%
data.head()
# Out:
#               time         Im  flag
# 0  2018/11/26 0:00  23.700001     1
# 1  2018/11/26 0:00  23.700001     1
# 2  2018/11/26 0:00  23.700001     1
# 3  2018/11/26 0:00  23.700001     1
# 4  2018/11/26 0:00  23.700001     1

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.xlim(0, 40000)
for i in np.unique(data.flag):
    plt.plot(data.Im[data.flag==i])

# %%
from fastdtw import fastdtw
dis=np.zeros((len(np.unique(data.flag)),len(np.unique(data.flag))))

for i in range(len(np.unique(data.flag))):
    for j in range(i+1, len(np.unique(data.flag))):
        distance, path = fastdtw(data.Im[data.flag==np.unique(data.flag)[i]],
                                data.Im[data.flag==np.unique(data.flag)[j]])
    #print(distance)
        dis[i,j]=distance
dis
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   import sys
# array([[    0.        ,  3136.0499047 ,  3373.80016405,  2234.84995809,
#          2705.09997044,  2473.49996425,  3466.05016405,  4146.59991819,
#         11799.89979583,  6559.19931675,  4164.44993757,  4480.5499104 ,
#          2222.99986028,  5421.74980999,  3530.55006811,  3247.65002193,
#          3643.34992913,  4798.19975993,  3918.44990097,  4339.79975365,
#          4013.24989601,  4073.24981141,  2815.35000871],
#        [    0.        ,     0.        ,  5987.2501862 ,  4664.70004994,
#          5308.94977846,  4583.25014713,  5691.59980848,  5517.74981   ,
#          9614.84944558,  5528.54986957,  6012.29990709,  7326.49966938,
#          4548.44996983,  4659.75006793,  6421.79974465,  5857.80001729,
# ...

# %%
dis=dis.T+dis

# %%
pd.DataFrame(dis).to_csv("distance.csv")

# %%
第一类=pd.read_csv("第一类.csv")
第二类=pd.read_csv("第二类.csv")
第三类=pd.read_csv("第三类.csv")
#第四类=pd.read_csv("第四类.csv")
#第五类=pd.read_csv("第五类.csv")
#第六类=pd.read_csv("第六类.csv")
#第七类=pd.read_csv("第七类.csv")

# %%
plt.figure(figsize=(20,5))
plt.xlim(0,40000)
#plt.plot(data.Im,color="red")
for i in 第一类.x:
        plt.plot(data.Im[data.flag==i],color="blue")   
for i in 第二类.x:
        plt.plot(data.Im[data.flag==i],color="black")
for i in 第三类.x:
        plt.plot(data.Im[data.flag==i],color="orange")
#for i in 第四类.x:
#        plt.plot(data.Im[data.flag==i],color="red")
#for i in 第五类.x:
#        plt.plot(data.Im[data.flag==i],color="pink")
#for i in 第六类.x:
#        plt.plot(data.Im[data.flag==i],color="yellow")
#for i in 第七类.x:
#        plt.plot(data.Im[data.flag==i],color="green")

# %%
plt.figure(figsize=(20,5))
plt.xlim(0, 700)
plt.ylim(0,35)
plt.plot(data.Im[data.flag==23])
